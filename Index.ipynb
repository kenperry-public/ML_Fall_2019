# %% [markdown]
# # Week 1
# - [Course Overview](Course_overview.ipynb)
# - [Getting Started](Getting_Started.ipynb)
# - [Intro to Classical ML](Intro_Classical_ML.ipynb)
#
# # Week 2
# - [Recipe for Machine Learning](Recipe_for_ML.ipynb)
#
# # Week 3
# - [Classification and Categorical Variables](Classification_and_Non_Numerical_Data.ipynb)
#
# # Week 4
# - [Classification continued](Classification_continued.ipynb)
# - [Cost functions](Cost_functions.ipynb)
# - [Transformations](Transformations.ipynb)
#
# # Week 5
# - [Naive Bayes](Naive_Bayes.ipynb)
# - [Decision Trees](Decision_Trees.ipynb)
#
#
# # Week 6
# - [Support Vector Machines](SVM.ipynb)
# - [Gradient Descent](Gradient_Descent.ipynb)
# - [Interpretation: Linear Models](Linear_Model_Interpretation.ipynb)
# - [Missing Data](Missing_Data.ipynb)
#
# # Week 7
# - [Missing Data](Missing_Data.ipynb) *continued*
# - [Becoming a Successful Data Scientist](Successful_Data_Scientist.ipynb)
# - [Unsupervised Learning](Unsupervised.ipynb)
#
# # Week 8
# - [Intro to Neural Networks](Neural%20Networks.ipynb)
# - Coding Neural Networks: Tensorflow, Keras
#     - [Intro to Keras](Tensorflow_Keras.ipynb)
#     - **Colab**: [DNN Tensorflow example Notebook from github](https://colab.research.google.com/github/kenperry-public/ML_Fall_2019/blob/master/DNN_TensorFlow_example.ipynb)
# - [Computation Graphs](Computation_Graphs.ipynb)
#     - **Colab**: [Raw_TensorFlow example Notebook from github](https://colab.research.google.com/github/kenperry-public/ML_Fall_2019/blob/master/Raw_TensorFlow.ipynb)
#
# # Week 9
#
# - [Practical Keras](Tensorflow_Keras_Practical.ipynb)
# - Practical Colab
#    - **Colab**: [Practical Colab Notebook from github](https://colab.research.google.com/github/kenperry-public/ML_Fall_2019/blob/master/Colab_practical.ipynb)
# - [Universal Function Approximation](Universal_Function_Approximator.ipynb)
# - [Interpretation: preview](Interpretation_preview.ipynb)
#
# - [Autoencoders and Generative Models](Autoencoders_and_Generative_Models.ipynb)
#     - **Colab**: [Autoencoder example from github](https://colab.research.google.com/github/kenperry-public/ML_Fall_2019/blob/master/Autoencoder_example.ipynb)
#
#
# # Week 10
# - [Tensors: Matrix gradients](Matrix_Gradient.ipynb)
# - [Training Neural Networks](Training_Neural_Networks.ipynb)
#
# # Week 11
# - DNN Homework review
#     - **Colab**: [DNN MNIST example from github](https://colab.research.google.com/github/kenperry-public/ML_Fall_2019/blob/master/DNN_MNIST.ipynb)
#
# - [Convolutional Neural Networks](CNN.ipynb)
#     - **Colab**: [CNN example from github](https://colab.research.google.com/github/kenperry-public/ML_Fall_2019/blob/master/CNN_demo.ipynb)
#
# - [Interpretation of Deep Learning Networks](Interpretation_of_DL.ipynb)
#
#
# # Week 12
# - [CNN: Space vs Time](CNN.ipynb) *continued*
# - [Transfer Learning](Transfer_Learning.ipynb)
#      - **Colab**: [Transfer Learning example from github](https://colab.research.google.com/github/kenperry-public/ML_Fall_2019/blob/master/TransferLearning_demo.ipynb)
# - [Recurrent Neural Networks](RNN.ipynb)
#     - **Colab**: [LSTM_text_generation from github](https://colab.research.google.com/github/kenperry-public/ML_Fall_2019/blob/master/Keras_examples_LSTM_text_generation.ipynb)
# - [LSTM](LSTM.ipynb)
# - [Adversarial Examples](Adversarial_Examples.ipynb)
