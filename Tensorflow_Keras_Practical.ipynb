# %%
# %run Latex_macros.ipynb
# Out:
# $$
# \newcommand{\x}{\mathbf{x}}
# \newcommand{\y}{\mathbf{y}}
# \newcommand{\b}{\mathbf{b}}
# \newcommand{\c}{\mathbf{c}}
# \newcommand{\e}{\mathbf{e}}
# \newcommand{\z}{\mathbf{z}}
# \newcommand{\h}{\mathbf{h}}
# \newcommand{\w}{\mathbf{w}}
# \newcommand{\W}{\mathbf{W}}
# \newcommand{\X}{\mathbf{X}}
# \newcommand{\KL}{\mathbf{KL}}
# \newcommand{\E}{{\mathbb{E}}}
# \newcommand{\ip}{\mathbf{{(i)}}}
# % \ll indexes a layer; we can change the actual letter
# \newcommand{\ll}{l}
# \newcommand{\llp}{{(\ll)}}
# %
# \newcommand{\tp}{\mathbf{{(t)}}}
# \newcommand{\loss}{\mathcal{L}}
# \newcommand{\cost}{\mathcal{L}}
# %
# % Functions with arguments
# \def\xsy#1#2{#1^#2}
# \def\rand#1{\tilde{#1}}
# \def\randx{\rand{\x}}
# \def\randy{\rand{\y}}
# %
# \def\argmax#1{\underset{#1} {\operatorname{argmax}} }
# \def\argmin#1{\underset{#1} {\operatorname{argmin}} }
# \def\max#1{\underset{#1} {\operatorname{max}} }
# \def\min#1{\underset{#1} {\operatorname{min}} }
# %
# \def\pr#1{\mathcal{p}(#1)}
# \def\cnt#1{\mathcal{count}_{#1}}
# \def\node#1{\mathbb{#1}}
# $$
# Macro `_latex_std_` created. To execute, type its name (without quotes).
# === Macro contents: ===
# get_ipython().run_line_magic('run', 'Latex_macros.ipynb')

# %% [markdown]
# # Keras: practical aspects
#
# The topics to be covered are:
#
# - Callbacks
#
#     - Early stopping
#
#     - Checkpoints
#
# - Saving/Restoring a Model
#
# - Interrupting/Resuming Train

# %% [markdown]
# ## Detour: DNN Tensorflow notebook on Colab
#
# We will now switch to a notebook running on Google Colab
#
# [DNN Tensorflow example Notebook from github](https://colab.research.google.com/github/kenperry-public/ML_Fall_2019/blob/master/DNN_TensorFlow_example.ipynb)

# %% [markdown]
# # Colab
#
# The topics to be covered are:
# - Testing whether your notebook is running under Colab
# - Mounting your Google Drive
# - Working with your Google Drive

# %% [markdown]
# ## Detour: Practical Colab notebook on Colab
#
# We will now switch to a notebook running on Google Colab
#
# [Practical Colab Notebook from github](https://colab.research.google.com/github/kenperry-public/ML_Fall_2019/blob/master/Colab_practical.ipynb)

# %%
print("Done")
# Out:
# Done
