# %% [markdown]
# Derived from
#
# Keras blog: https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html

# %% [markdown]
# Mount my Google Drive (have data stored there)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# # Download the Cats and Dogs dataset

# %% [markdown]
# Unzip the Cats and Dogs images into pwd (i.e., /content).  That is where the code is looking

# %%
# !pwd
# !tar -zxvf '/content/gdrive/My Drive/data/cats_and_dogs/cats_and_dogs_data.tgz'
# !cd /content
# Out:
# /content
# data/
# data/validation/
# data/validation/dogs/
# data/validation/dogs/dog126.jpg
# data/validation/dogs/dog124.jpg
# data/validation/dogs/dog040.jpg
# data/validation/dogs/dog388.jpg
# data/validation/dogs/dog042.jpg
# data/validation/dogs/dog357.jpg
# data/validation/dogs/dog368.jpg
# data/validation/dogs/dog012.jpg
# data/validation/dogs/dog254.jpg
# data/validation/dogs/dog123.jpg
# data/validation/dogs/dog191.jpg
# data/validation/dogs/dog273.jpg
# data/validation/dogs/dog209.jpg
# data/validation/dogs/dog328.jpg
# data/validation/dogs/dog312.jpg
# data/validation/dogs/dog222.jpg
# data/validation/dogs/dog106.jpg
# data/validation/dogs/dog145.jpg
# data/validation/dogs/dog301.jpg
# data/validation/dogs/dog394.jpg
# data/validation/dogs/dog369.jpg
# data/validation/dogs/dog250.jpg
# data/validation/dogs/dog313.jpg
# data/validation/dogs/dog283.jpg
# data/validation/dogs/dog336.jpg
# data/validation/dogs/dog156.jpg
# data/validation/dogs/dog380.jpg
# data/validation/dogs/dog345.jpg
# data/validation/dogs/dog044.jpg
# data/validation/dogs/dog286.jpg
# data/validation/dogs/dog318.jpg
# data/validation/dogs/dog214.jpg
# data/validation/dogs/dog002.jpg
# data/validation/dogs/dog169.jpg
# data/validation/dogs/dog180.jpg
# data/validation/dogs/dog303.jpg
# data/validation/dogs/dog146.jpg
# data/validation/dogs/dog386.jpg
# data/validation/dogs/dog239.jpg
# data/validation/dogs/dog269.jpg
# data/validation/dogs/dog098.jpg
# data/validation/dogs/dog070.jpg
# data/validation/dogs/dog163.jpg
# data/validation/dogs/dog396.jpg
# data/validation/dogs/dog119.jpg
# data/validation/dogs/dog356.jpg
# data/validation/dogs/dog029.jpg
# data/validation/dogs/dog376.jpg
# data/validation/dogs/dog053.jpg
# data/validation/dogs/dog226.jpg
# data/validation/dogs/dog219.jpg
# data/validation/dogs/dog306.jpg
# data/validation/dogs/dog060.jpg
# data/validation/dogs/dog252.jpg
# data/validation/dogs/dog091.jpg
# data/validation/dogs/dog062.jpg
# data/validation/dogs/dog346.jpg
# data/validation/dogs/dog132.jpg
# data/validation/dogs/dog198.jpg
# data/validation/dogs/dog302.jpg
# data/validation/dogs/dog112.jpg
# data/validation/dogs/dog323.jpg
# data/validation/dogs/dog398.jpg
# data/validation/dogs/dog036.jpg
# data/validation/dogs/dog073.jpg
# data/validation/dogs/dog135.jpg
# data/validation/dogs/dog205.jpg
# data/validation/dogs/dog045.jpg
# data/validation/dogs/dog245.jpg
# data/validation/dogs/dog325.jpg
# data/validation/dogs/dog243.jpg
# data/validation/dogs/dog260.jpg
# data/validation/dogs/dog054.jpg
# data/validation/dogs/dog154.jpg
# data/validation/dogs/dog277.jpg
# data/validation/dogs/dog387.jpg
# data/validation/dogs/dog193.jpg
# data/validation/dogs/dog289.jpg
# data/validation/dogs/dog332.jpg
# data/validation/dogs/dog324.jpg
# data/validation/dogs/dog167.jpg
# data/validation/dogs/dog022.jpg
# data/validation/dogs/dog055.jpg
# data/validation/dogs/dog158.jpg
# data/validation/dogs/dog015.jpg
# data/validation/dogs/dog168.jpg
# data/validation/dogs/dog354.jpg
# data/validation/dogs/dog206.jpg
# data/validation/dogs/dog339.jpg
# data/validation/dogs/dog379.jpg
# data/validation/dogs/dog159.jpg
# data/validation/dogs/dog137.jpg
# data/validation/dogs/dog298.jpg
# data/validation/dogs/dog095.jpg
# data/validation/dogs/dog308.jpg
# data/validation/dogs/dog282.jpg
# data/validation/dogs/dog349.jpg
# data/validation/dogs/dog292.jpg
# data/validation/dogs/dog244.jpg
# data/validation/dogs/dog274.jpg
# data/validation/dogs/dog192.jpg
# data/validation/dogs/dog291.jpg
# data/validation/dogs/dog021.jpg
# data/validation/dogs/dog235.jpg
# data/validation/dogs/dog361.jpg
# data/validation/dogs/dog081.jpg
# data/validation/dogs/dog047.jpg
# data/validation/dogs/dog212.jpg
# data/validation/dogs/dog084.jpg
# data/validation/dogs/dog150.jpg
# data/validation/dogs/dog213.jpg
# data/validation/dogs/dog196.jpg
# data/validation/dogs/dog360.jpg
# data/validation/dogs/dog026.jpg
# data/validation/dogs/dog246.jpg
# data/validation/dogs/dog108.jpg
# data/validation/dogs/dog294.jpg
# data/validation/dogs/dog094.jpg
# data/validation/dogs/dog364.jpg
# data/validation/dogs/dog314.jpg
# data/validation/dogs/dog174.jpg
# data/validation/dogs/dog207.jpg
# data/validation/dogs/dog288.jpg
# data/validation/dogs/dog229.jpg
# data/validation/dogs/dog117.jpg
# data/validation/dogs/dog140.jpg
# data/validation/dogs/dog185.jpg
# data/validation/dogs/dog232.jpg
# data/validation/dogs/dog215.jpg
# data/validation/dogs/dog149.jpg
# data/validation/dogs/dog309.jpg
# data/validation/dogs/dog121.jpg
# data/validation/dogs/dog371.jpg
# data/validation/dogs/dog129.jpg
# data/validation/dogs/dog223.jpg
# data/validation/dogs/dog280.jpg
# data/validation/dogs/dog310.jpg
# data/validation/dogs/dog227.jpg
# data/validation/dogs/dog365.jpg
# data/validation/dogs/dog068.jpg
# data/validation/dogs/dog319.jpg
# data/validation/dogs/dog089.jpg
# data/validation/dogs/dog322.jpg
# data/validation/dogs/dog114.jpg
# data/validation/dogs/dog097.jpg
# data/validation/dogs/dog153.jpg
# data/validation/dogs/dog377.jpg
# data/validation/dogs/dog052.jpg
# data/validation/dogs/dog078.jpg
# data/validation/dogs/dog101.jpg
# data/validation/dogs/dog115.jpg
# data/validation/dogs/dog279.jpg
# data/validation/dogs/dog171.jpg
# data/validation/dogs/dog385.jpg
# data/validation/dogs/dog203.jpg
# data/validation/dogs/dog255.jpg
# data/validation/dogs/dog353.jpg
# data/validation/dogs/dog056.jpg
# data/validation/dogs/dog347.jpg
# data/validation/dogs/dog057.jpg
# data/validation/dogs/dog253.jpg
# data/validation/dogs/dog051.jpg
# data/validation/dogs/dog304.jpg
# data/validation/dogs/dog077.jpg
# data/validation/dogs/dog272.jpg
# data/validation/dogs/dog093.jpg
# data/validation/dogs/dog295.jpg
# data/validation/dogs/dog267.jpg
# data/validation/dogs/dog265.jpg
# data/validation/dogs/dog107.jpg
# data/validation/dogs/dog155.jpg
# data/validation/dogs/dog261.jpg
# data/validation/dogs/dog340.jpg
# data/validation/dogs/dog092.jpg
# data/validation/dogs/dog307.jpg
# data/validation/dogs/dog080.jpg
# data/validation/dogs/dog290.jpg
# data/validation/dogs/dog370.jpg
# data/validation/dogs/dog189.jpg
# data/validation/dogs/dog165.jpg
# data/validation/dogs/dog033.jpg
# data/validation/dogs/dog287.jpg
# data/validation/dogs/dog391.jpg
# data/validation/dogs/dog258.jpg
# data/validation/dogs/dog228.jpg
# data/validation/dogs/dog201.jpg
# data/validation/dogs/dog148.jpg
# data/validation/dogs/dog278.jpg
# data/validation/dogs/dog275.jpg
# data/validation/dogs/dog018.jpg
# data/validation/dogs/dog003.jpg
# data/validation/dogs/dog122.jpg
# data/validation/dogs/dog023.jpg
# data/validation/dogs/dog320.jpg
# data/validation/dogs/dog384.jpg
# data/validation/dogs/dog183.jpg
# data/validation/dogs/dog147.jpg
# data/validation/dogs/dog230.jpg
# data/validation/dogs/dog350.jpg
# data/validation/dogs/dog293.jpg
# data/validation/dogs/dog160.jpg
# data/validation/dogs/dog341.jpg
# data/validation/dogs/dog182.jpg
# data/validation/dogs/dog197.jpg
# data/validation/dogs/dog141.jpg
# data/validation/dogs/dog130.jpg
# data/validation/dogs/dog348.jpg
# data/validation/dogs/dog399.jpg
# data/validation/dogs/dog161.jpg
# data/validation/dogs/dog019.jpg
# data/validation/dogs/dog315.jpg
# data/validation/dogs/dog330.jpg
# data/validation/dogs/dog075.jpg
# data/validation/dogs/dog327.jpg
# data/validation/dogs/dog392.jpg
# data/validation/dogs/dog241.jpg
# data/validation/dogs/dog162.jpg
# data/validation/dogs/dog242.jpg
# data/validation/dogs/dog329.jpg
# data/validation/dogs/dog351.jpg
# data/validation/dogs/dog276.jpg
# data/validation/dogs/dog048.jpg
# data/validation/dogs/dog297.jpg
# data/validation/dogs/dog157.jpg
# data/validation/dogs/dog152.jpg
# data/validation/dogs/dog395.jpg
# data/validation/dogs/dog374.jpg
# data/validation/dogs/dog270.jpg
# data/validation/dogs/dog017.jpg
# data/validation/dogs/dog110.jpg
# data/validation/dogs/dog220.jpg
# data/validation/dogs/dog224.jpg
# data/validation/dogs/dog234.jpg
# data/validation/dogs/dog311.jpg
# data/validation/dogs/dog202.jpg
# data/validation/dogs/dog142.jpg
# data/validation/dogs/dog299.jpg
# data/validation/dogs/dog032.jpg
# data/validation/dogs/dog342.jpg
# data/validation/dogs/dog088.jpg
# data/validation/dogs/dog338.jpg
# data/validation/dogs/dog039.jpg
# data/validation/dogs/dog025.jpg
# data/validation/dogs/dog061.jpg
# data/validation/dogs/dog187.jpg
# data/validation/dogs/dog049.jpg
# data/validation/dogs/dog100.jpg
# data/validation/dogs/dog264.jpg
# data/validation/dogs/dog321.jpg
# data/validation/dogs/dog373.jpg
# data/validation/dogs/dog178.jpg
# data/validation/dogs/dog366.jpg
# data/validation/dogs/dog256.jpg
# data/validation/dogs/dog389.jpg
# data/validation/dogs/dog083.jpg
# data/validation/dogs/dog038.jpg
# data/validation/dogs/dog175.jpg
# data/validation/dogs/dog359.jpg
# data/validation/dogs/dog020.jpg
# data/validation/dogs/dog397.jpg
# data/validation/dogs/dog139.jpg
# data/validation/dogs/dog199.jpg
# data/validation/dogs/dog335.jpg
# data/validation/dogs/dog006.jpg
# data/validation/dogs/dog010.jpg
# data/validation/dogs/dog031.jpg
# data/validation/dogs/dog014.jpg
# data/validation/dogs/dog231.jpg
# data/validation/dogs/dog085.jpg
# data/validation/dogs/dog296.jpg
# data/validation/dogs/dog127.jpg
# data/validation/dogs/dog284.jpg
# data/validation/dogs/dog383.jpg
# data/validation/dogs/dog005.jpg
# data/validation/dogs/dog263.jpg
# data/validation/dogs/dog001.jpg
# data/validation/dogs/dog050.jpg
# data/validation/dogs/dog082.jpg
# data/validation/dogs/dog216.jpg
# data/validation/dogs/dog125.jpg
# data/validation/dogs/dog030.jpg
# data/validation/dogs/dog067.jpg
# data/validation/dogs/dog034.jpg
# data/validation/dogs/dog375.jpg
# data/validation/dogs/dog343.jpg
# data/validation/dogs/dog337.jpg
# data/validation/dogs/dog004.jpg
# data/validation/dogs/dog352.jpg
# data/validation/dogs/dog024.jpg
# data/validation/dogs/dog281.jpg
# data/validation/dogs/dog326.jpg
# data/validation/dogs/dog113.jpg
# data/validation/dogs/dog164.jpg
# data/validation/dogs/dog035.jpg
# data/validation/dogs/dog188.jpg
# data/validation/dogs/dog181.jpg
# data/validation/dogs/dog194.jpg
# data/validation/dogs/dog103.jpg
# data/validation/dogs/dog118.jpg
# data/validation/dogs/dog316.jpg
# data/validation/dogs/dog285.jpg
# data/validation/dogs/dog358.jpg
# data/validation/dogs/dog007.jpg
# data/validation/dogs/dog271.jpg
# data/validation/dogs/dog186.jpg
# data/validation/dogs/dog172.jpg
# data/validation/dogs/dog071.jpg
# data/validation/dogs/dog211.jpg
# data/validation/dogs/dog251.jpg
# data/validation/dogs/dog151.jpg
# data/validation/dogs/dog300.jpg
# data/validation/dogs/dog344.jpg
# data/validation/dogs/dog400.jpg
# data/validation/dogs/dog013.jpg
# data/validation/dogs/dog116.jpg
# data/validation/dogs/dog200.jpg
# data/validation/dogs/dog268.jpg
# data/validation/dogs/dog217.jpg
# data/validation/dogs/dog363.jpg
# data/validation/dogs/dog305.jpg
# data/validation/dogs/dog372.jpg
# data/validation/dogs/dog381.jpg
# data/validation/dogs/dog011.jpg
# data/validation/dogs/dog378.jpg
# data/validation/dogs/dog046.jpg
# data/validation/dogs/dog131.jpg
# data/validation/dogs/dog109.jpg
# data/validation/dogs/dog096.jpg
# data/validation/dogs/dog043.jpg
# data/validation/dogs/dog065.jpg
# data/validation/dogs/dog317.jpg
# data/validation/dogs/dog138.jpg
# data/validation/dogs/dog063.jpg
# data/validation/dogs/dog355.jpg
# data/validation/dogs/dog143.jpg
# data/validation/dogs/dog190.jpg
# data/validation/dogs/dog074.jpg
# data/validation/dogs/dog262.jpg
# data/validation/dogs/dog008.jpg
# data/validation/dogs/dog027.jpg
# data/validation/dogs/dog009.jpg
# data/validation/dogs/dog177.jpg
# data/validation/dogs/dog041.jpg
# data/validation/dogs/dog016.jpg
# data/validation/dogs/dog079.jpg
# data/validation/dogs/dog170.jpg
# data/validation/dogs/dog382.jpg
# data/validation/dogs/dog237.jpg
# data/validation/dogs/dog225.jpg
# data/validation/dogs/dog393.jpg
# data/validation/dogs/dog028.jpg
# data/validation/dogs/dog166.jpg
# data/validation/dogs/dog195.jpg
# data/validation/dogs/dog144.jpg
# data/validation/dogs/dog099.jpg
# data/validation/dogs/dog105.jpg
# data/validation/dogs/dog221.jpg
# data/validation/dogs/dog257.jpg
# data/validation/dogs/dog259.jpg
# data/validation/dogs/dog236.jpg
# data/validation/dogs/dog173.jpg
# data/validation/dogs/dog059.jpg
# data/validation/dogs/dog238.jpg
# data/validation/dogs/dog066.jpg
# data/validation/dogs/dog248.jpg
# data/validation/dogs/dog064.jpg
# data/validation/dogs/dog334.jpg
# data/validation/dogs/dog204.jpg
# data/validation/dogs/dog266.jpg
# data/validation/dogs/dog111.jpg
# data/validation/dogs/dog128.jpg
# data/validation/dogs/dog076.jpg
# data/validation/dogs/dog133.jpg
# data/validation/dogs/dog069.jpg
# data/validation/dogs/dog208.jpg
# data/validation/dogs/dog247.jpg
# data/validation/dogs/dog058.jpg
# data/validation/dogs/dog218.jpg
# data/validation/dogs/dog102.jpg
# data/validation/dogs/dog331.jpg
# data/validation/dogs/dog136.jpg
# data/validation/dogs/dog179.jpg
# data/validation/dogs/dog090.jpg
# data/validation/dogs/dog087.jpg
# data/validation/dogs/dog104.jpg
# data/validation/dogs/dog176.jpg
# data/validation/dogs/dog184.jpg
# data/validation/dogs/dog249.jpg
# data/validation/dogs/dog240.jpg
# data/validation/dogs/dog233.jpg
# data/validation/dogs/dog390.jpg
# data/validation/dogs/dog362.jpg
# data/validation/dogs/dog367.jpg
# data/validation/dogs/dog120.jpg
# data/validation/dogs/dog333.jpg
# data/validation/dogs/dog037.jpg
# data/validation/dogs/dog210.jpg
# data/validation/dogs/dog072.jpg
# data/validation/dogs/dog134.jpg
# data/validation/dogs/dog086.jpg
# data/validation/cats/
# data/validation/cats/cat029.jpg
# data/validation/cats/cat122.jpg
# data/validation/cats/cat323.jpg
# data/validation/cats/cat148.jpg
# data/validation/cats/cat004.jpg
# data/validation/cats/cat159.jpg
# data/validation/cats/cat071.jpg
# data/validation/cats/cat080.jpg
# data/validation/cats/cat137.jpg
# data/validation/cats/cat006.jpg
# data/validation/cats/cat254.jpg
# data/validation/cats/cat083.jpg
# data/validation/cats/cat366.jpg
# data/validation/cats/cat028.jpg
# data/validation/cats/cat234.jpg
# data/validation/cats/cat343.jpg
# data/validation/cats/cat260.jpg
# data/validation/cats/cat145.jpg
# data/validation/cats/cat095.jpg
# data/validation/cats/cat268.jpg
# data/validation/cats/cat258.jpg
# data/validation/cats/cat298.jpg
# data/validation/cats/cat104.jpg
# data/validation/cats/cat073.jpg
# data/validation/cats/cat380.jpg
# data/validation/cats/cat267.jpg
# data/validation/cats/cat001.jpg
# data/validation/cats/cat320.jpg
# data/validation/cats/cat376.jpg
# data/validation/cats/cat114.jpg
# data/validation/cats/cat301.jpg
# data/validation/cats/cat262.jpg
# data/validation/cats/cat066.jpg
# data/validation/cats/cat299.jpg
# data/validation/cats/cat171.jpg
# data/train/
# data/train/dogs/
# data/train/dogs/dog717.jpg
# data/train/dogs/dog983.jpg
# data/train/dogs/dog725.jpg
# data/train/dogs/dog126.jpg
# data/train/dogs/dog124.jpg
# data/train/dogs/dog514.jpg
# data/train/dogs/dog592.jpg
# data/train/dogs/dog927.jpg
# data/train/dogs/dog709.jpg
# data/train/dogs/dog040.jpg
# data/train/dogs/dog388.jpg
# data/train/dogs/dog042.jpg
# data/train/dogs/dog357.jpg
# data/train/dogs/dog368.jpg
# data/train/dogs/dog920.jpg
# data/train/dogs/dog682.jpg
# data/train/dogs/dog012.jpg
# data/train/dogs/dog254.jpg
# data/train/dogs/dog418.jpg
# data/train/dogs/dog629.jpg
# data/train/dogs/dog123.jpg
# data/train/dogs/dog684.jpg
# data/train/dogs/dog623.jpg
# data/train/dogs/dog961.jpg
# data/train/dogs/dog598.jpg
# data/train/dogs/dog446.jpg
# data/train/dogs/dog715.jpg
# data/train/dogs/dog526.jpg
# data/train/dogs/dog956.jpg
# data/train/dogs/dog703.jpg
# data/train/dogs/dog716.jpg
# data/train/dogs/dog529.jpg
# data/train/dogs/dog490.jpg
# data/train/dogs/dog926.jpg
# data/train/dogs/dog877.jpg
# data/train/dogs/dog191.jpg
# data/train/dogs/dog273.jpg
# data/train/dogs/dog470.jpg
# data/train/dogs/dog630.jpg
# data/train/dogs/dog753.jpg
# data/train/dogs/dog467.jpg
# data/train/dogs/dog481.jpg
# data/train/dogs/dog757.jpg
# data/train/dogs/dog209.jpg
# data/train/dogs/dog722.jpg
# data/train/dogs/dog328.jpg
# data/train/dogs/dog895.jpg
# data/train/dogs/dog957.jpg
# data/train/dogs/dog312.jpg
# data/train/dogs/dog910.jpg
# data/train/dogs/dog222.jpg
# data/train/dogs/dog106.jpg
# data/train/dogs/dog405.jpg
# data/train/dogs/dog145.jpg
# data/train/dogs/dog798.jpg
# data/train/dogs/dog301.jpg
# data/train/dogs/dog699.jpg
# data/train/dogs/dog751.jpg
# data/train/dogs/dog394.jpg
# data/train/dogs/dog442.jpg
# data/train/dogs/dog603.jpg
# data/train/dogs/dog820.jpg
# data/train/dogs/dog936.jpg
# data/train/dogs/dog628.jpg
# data/train/dogs/dog692.jpg
# data/train/dogs/dog369.jpg
# data/train/dogs/dog250.jpg
# data/train/dogs/dog643.jpg
# data/train/dogs/dog488.jpg
# data/train/dogs/dog438.jpg
# data/train/dogs/dog313.jpg
# data/train/dogs/dog813.jpg
# data/train/dogs/dog283.jpg
# data/train/dogs/dog831.jpg
# data/train/dogs/dog988.jpg
# data/train/dogs/dog834.jpg
# data/train/dogs/dog336.jpg
# data/train/dogs/dog609.jpg
# data/train/dogs/dog156.jpg
# data/train/dogs/dog423.jpg
# data/train/dogs/dog849.jpg
# data/train/dogs/dog686.jpg
# data/train/dogs/dog380.jpg
# data/train/dogs/dog345.jpg
# data/train/dogs/dog044.jpg
# data/train/dogs/dog286.jpg
# data/train/dogs/dog972.jpg
# data/train/dogs/dog597.jpg
# data/train/dogs/dog647.jpg
# data/train/dogs/dog887.jpg
# data/train/dogs/dog940.jpg
# data/train/dogs/dog823.jpg
# data/train/dogs/dog635.jpg
# data/train/dogs/dog318.jpg
# data/train/dogs/dog829.jpg
# data/train/dogs/dog214.jpg
# data/train/dogs/dog559.jpg
# data/train/dogs/dog971.jpg
# data/train/dogs/dog002.jpg
# data/train/dogs/dog806.jpg
# data/train/dogs/dog784.jpg
# data/train/dogs/dog646.jpg
# data/train/dogs/dog523.jpg
# data/train/dogs/dog169.jpg
# data/train/dogs/dog180.jpg
# data/train/dogs/dog303.jpg
# data/train/dogs/dog520.jpg
# data/train/dogs/dog915.jpg
# data/train/dogs/dog146.jpg
# data/train/dogs/dog666.jpg
# data/train/dogs/dog734.jpg
# data/train/dogs/dog484.jpg
# data/train/dogs/dog386.jpg
# data/train/dogs/dog832.jpg
# data/train/dogs/dog667.jpg
# data/train/dogs/dog239.jpg
# data/train/dogs/dog269.jpg
# data/train/dogs/dog543.jpg
# data/train/dogs/dog777.jpg
# data/train/dogs/dog098.jpg
# data/train/dogs/dog761.jpg
# data/train/dogs/dog959.jpg
# data/train/dogs/dog070.jpg
# data/train/dogs/dog551.jpg
# data/train/dogs/dog163.jpg
# data/train/dogs/dog483.jpg
# data/train/dogs/dog396.jpg
# data/train/dogs/dog748.jpg
# data/train/dogs/dog663.jpg
# data/train/dogs/dog119.jpg
# data/train/dogs/dog356.jpg
# data/train/dogs/dog439.jpg
# data/train/dogs/dog029.jpg
# data/train/dogs/dog376.jpg
# data/train/dogs/dog053.jpg
# data/train/dogs/dog455.jpg
# data/train/dogs/dog875.jpg
# data/train/dogs/dog668.jpg
# data/train/dogs/dog226.jpg
# data/train/dogs/dog219.jpg
# data/train/dogs/dog872.jpg
# data/train/dogs/dog714.jpg
# data/train/dogs/dog306.jpg
# data/train/dogs/dog060.jpg
# data/train/dogs/dog828.jpg
# data/train/dogs/dog252.jpg
# data/train/dogs/dog497.jpg
# data/train/dogs/dog466.jpg
# data/train/dogs/dog869.jpg
# data/train/dogs/dog976.jpg
# data/train/dogs/dog091.jpg
# data/train/dogs/dog718.jpg
# data/train/dogs/dog659.jpg
# data/train/dogs/dog588.jpg
# data/train/dogs/dog062.jpg
# data/train/dogs/dog556.jpg
# data/train/dogs/dog346.jpg
# data/train/dogs/dog132.jpg
# data/train/dogs/dog807.jpg
# data/train/dogs/dog198.jpg
# data/train/dogs/dog860.jpg
# data/train/dogs/dog736.jpg
# data/train/dogs/dog739.jpg
# data/train/dogs/dog997.jpg
# data/train/dogs/dog302.jpg
# data/train/dogs/dog665.jpg
# data/train/dogs/dog112.jpg
# data/train/dogs/dog485.jpg
# data/train/dogs/dog790.jpg
# data/train/dogs/dog323.jpg
# data/train/dogs/dog942.jpg
# data/train/dogs/dog590.jpg
# data/train/dogs/dog398.jpg
# data/train/dogs/dog868.jpg
# data/train/dogs/dog774.jpg
# data/train/dogs/dog672.jpg
# data/train/dogs/dog620.jpg
# data/train/dogs/dog977.jpg
# data/train/dogs/dog582.jpg
# data/train/dogs/dog881.jpg
# data/train/dogs/dog698.jpg
# data/train/dogs/dog726.jpg
# data/train/dogs/dog036.jpg
# data/train/dogs/dog499.jpg
# data/train/dogs/dog073.jpg
# data/train/dogs/dog512.jpg
# data/train/dogs/dog135.jpg
# data/train/dogs/dog752.jpg
# data/train/dogs/dog205.jpg
# data/train/dogs/dog508.jpg
# data/train/dogs/dog045.jpg
# data/train/dogs/dog631.jpg
# data/train/dogs/dog794.jpg
# data/train/dogs/dog697.jpg
# data/train/dogs/dog245.jpg
# data/train/dogs/dog325.jpg
# data/train/dogs/dog243.jpg
# data/train/dogs/dog600.jpg
# data/train/dogs/dog260.jpg
# data/train/dogs/dog407.jpg
# data/train/dogs/dog924.jpg
# data/train/dogs/dog054.jpg
# data/train/dogs/dog154.jpg
# data/train/dogs/dog277.jpg
# data/train/dogs/dog387.jpg
# data/train/dogs/dog902.jpg
# data/train/dogs/dog193.jpg
# data/train/dogs/dog878.jpg
# data/train/dogs/dog289.jpg
# data/train/dogs/dog332.jpg
# data/train/dogs/dog448.jpg
# data/train/dogs/dog1000.jpg
# data/train/dogs/dog324.jpg
# data/train/dogs/dog167.jpg
# data/train/dogs/dog605.jpg
# data/train/dogs/dog721.jpg
# data/train/dogs/dog022.jpg
# data/train/dogs/dog055.jpg
# data/train/dogs/dog850.jpg
# data/train/dogs/dog949.jpg
# data/train/dogs/dog674.jpg
# data/train/dogs/dog437.jpg
# data/train/dogs/dog801.jpg
# data/train/dogs/dog158.jpg
# data/train/dogs/dog015.jpg
# data/train/dogs/dog168.jpg
# data/train/dogs/dog435.jpg
# data/train/dogs/dog354.jpg
# data/train/dogs/dog841.jpg
# data/train/dogs/dog804.jpg
# data/train/dogs/dog654.jpg
# data/train/dogs/dog848.jpg
# data/train/dogs/dog919.jpg
# data/train/dogs/dog206.jpg
# data/train/dogs/dog685.jpg
# data/train/dogs/dog888.jpg
# data/train/dogs/dog782.jpg
# data/train/dogs/dog434.jpg
# data/train/dogs/dog795.jpg
# data/train/dogs/dog729.jpg
# data/train/dogs/dog541.jpg
# data/train/dogs/dog339.jpg
# data/train/dogs/dog379.jpg
# data/train/dogs/dog743.jpg
# data/train/dogs/dog627.jpg
# data/train/dogs/dog159.jpg
# data/train/dogs/dog137.jpg
# data/train/dogs/dog817.jpg
# data/train/dogs/dog839.jpg
# data/train/dogs/dog298.jpg
# data/train/dogs/dog431.jpg
# data/train/dogs/dog095.jpg
# data/train/dogs/dog780.jpg
# data/train/dogs/dog308.jpg
# data/train/dogs/dog530.jpg
# data/train/dogs/dog632.jpg
# data/train/dogs/dog419.jpg
# data/train/dogs/dog282.jpg
# data/train/dogs/dog349.jpg
# data/train/dogs/dog552.jpg
# data/train/dogs/dog292.jpg
# data/train/dogs/dog759.jpg
# data/train/dogs/dog244.jpg
# data/train/dogs/dog430.jpg
# data/train/dogs/dog274.jpg
# data/train/dogs/dog192.jpg
# data/train/dogs/dog967.jpg
# data/train/dogs/dog570.jpg
# data/train/dogs/dog655.jpg
# data/train/dogs/dog791.jpg
# data/train/dogs/dog676.jpg
# data/train/dogs/dog894.jpg
# data/train/dogs/dog449.jpg
# data/train/dogs/dog291.jpg
# data/train/dogs/dog769.jpg
# data/train/dogs/dog816.jpg
# data/train/dogs/dog893.jpg
# data/train/dogs/dog021.jpg
# data/train/dogs/dog970.jpg
# data/train/dogs/dog906.jpg
# data/train/dogs/dog708.jpg
# data/train/dogs/dog235.jpg
# data/train/dogs/dog867.jpg
# data/train/dogs/dog964.jpg
# data/train/dogs/dog812.jpg
# data/train/dogs/dog361.jpg
# data/train/dogs/dog690.jpg
# data/train/dogs/dog081.jpg
# data/train/dogs/dog047.jpg
# data/train/dogs/dog212.jpg
# data/train/dogs/dog945.jpg
# data/train/dogs/dog740.jpg
# data/train/dogs/dog084.jpg
# data/train/dogs/dog535.jpg
# data/train/dogs/dog150.jpg
# data/train/dogs/dog766.jpg
# data/train/dogs/dog213.jpg
# data/train/dogs/dog577.jpg
# data/train/dogs/dog453.jpg
# data/train/dogs/dog196.jpg
# data/train/dogs/dog360.jpg
# data/train/dogs/dog636.jpg
# data/train/dogs/dog026.jpg
# data/train/dogs/dog246.jpg
# data/train/dogs/dog610.jpg
# data/train/dogs/dog732.jpg
# data/train/dogs/dog528.jpg
# data/train/dogs/dog891.jpg
# data/train/dogs/dog994.jpg
# data/train/dogs/dog754.jpg
# data/train/dogs/dog561.jpg
# data/train/dogs/dog108.jpg
# data/train/dogs/dog991.jpg
# data/train/dogs/dog545.jpg
# data/train/dogs/dog890.jpg
# data/train/dogs/dog955.jpg
# data/train/dogs/dog776.jpg
# data/train/dogs/dog503.jpg
# data/train/dogs/dog416.jpg
# data/train/dogs/dog294.jpg
# data/train/dogs/dog441.jpg
# data/train/dogs/dog982.jpg
# data/train/dogs/dog440.jpg
# data/train/dogs/dog896.jpg
# data/train/dogs/dog786.jpg
# data/train/dogs/dog618.jpg
# data/train/dogs/dog410.jpg
# data/train/dogs/dog929.jpg
# data/train/dogs/dog487.jpg
# data/train/dogs/dog094.jpg
# data/train/dogs/dog500.jpg
# data/train/dogs/dog364.jpg
# data/train/dogs/dog805.jpg
# data/train/dogs/dog792.jpg
# data/train/dogs/dog844.jpg
# data/train/dogs/dog314.jpg
# data/train/dogs/dog174.jpg
# data/train/dogs/dog207.jpg
# data/train/dogs/dog432.jpg
# data/train/dogs/dog288.jpg
# data/train/dogs/dog229.jpg
# data/train/dogs/dog117.jpg
# data/train/dogs/dog680.jpg
# data/train/dogs/dog140.jpg
# data/train/dogs/dog474.jpg
# data/train/dogs/dog185.jpg
# data/train/dogs/dog232.jpg
# data/train/dogs/dog536.jpg
# data/train/dogs/dog215.jpg
# data/train/dogs/dog149.jpg
# data/train/dogs/dog521.jpg
# data/train/dogs/dog689.jpg
# data/train/dogs/dog727.jpg
# data/train/dogs/dog309.jpg
# data/train/dogs/dog121.jpg
# data/train/dogs/dog371.jpg
# data/train/dogs/dog129.jpg
# data/train/dogs/dog855.jpg
# data/train/dogs/dog429.jpg
# data/train/dogs/dog223.jpg
# data/train/dogs/dog626.jpg
# data/train/dogs/dog280.jpg
# data/train/dogs/dog775.jpg
# data/train/dogs/dog310.jpg
# data/train/dogs/dog464.jpg
# data/train/dogs/dog981.jpg
# data/train/dogs/dog534.jpg
# data/train/dogs/dog227.jpg
# data/train/dogs/dog974.jpg
# data/train/dogs/dog365.jpg
# data/train/dogs/dog068.jpg
# data/train/dogs/dog880.jpg
# data/train/dogs/dog319.jpg
# data/train/dogs/dog450.jpg
# data/train/dogs/dog966.jpg
# data/train/dogs/dog089.jpg
# data/train/dogs/dog322.jpg
# data/train/dogs/dog908.jpg
# data/train/dogs/dog469.jpg
# data/train/dogs/dog947.jpg
# data/train/dogs/dog114.jpg
# data/train/dogs/dog097.jpg
# data/train/dogs/dog153.jpg
# data/train/dogs/dog724.jpg
# data/train/dogs/dog758.jpg
# data/train/dogs/dog958.jpg
# data/train/dogs/dog771.jpg
# data/train/dogs/dog377.jpg
# data/train/dogs/dog854.jpg
# data/train/dogs/dog876.jpg
# data/train/dogs/dog460.jpg
# data/train/dogs/dog452.jpg
# data/train/dogs/dog883.jpg
# data/train/dogs/dog607.jpg
# data/train/dogs/dog052.jpg
# data/train/dogs/dog078.jpg
# data/train/dogs/dog772.jpg
# data/train/dogs/dog101.jpg
# data/train/dogs/dog115.jpg
# data/train/dogs/dog461.jpg
# data/train/dogs/dog564.jpg
# data/train/dogs/dog412.jpg
# data/train/dogs/dog533.jpg
# data/train/dogs/dog594.jpg
# data/train/dogs/dog279.jpg
# data/train/dogs/dog711.jpg
# data/train/dogs/dog171.jpg
# data/train/dogs/dog385.jpg
# data/train/dogs/dog562.jpg
# data/train/dogs/dog203.jpg
# data/train/dogs/dog255.jpg
# data/train/dogs/dog353.jpg
# data/train/dogs/dog420.jpg
# data/train/dogs/dog056.jpg
# data/train/dogs/dog347.jpg
# data/train/dogs/dog057.jpg
# data/train/dogs/dog723.jpg
# data/train/dogs/dog253.jpg
# data/train/dogs/dog574.jpg
# data/train/dogs/dog814.jpg
# data/train/dogs/dog879.jpg
# data/train/dogs/dog051.jpg
# data/train/dogs/dog304.jpg
# data/train/dogs/dog077.jpg
# data/train/dogs/dog943.jpg
# data/train/dogs/dog272.jpg
# data/train/dogs/dog093.jpg
# data/train/dogs/dog295.jpg
# data/train/dogs/dog542.jpg
# data/train/dogs/dog519.jpg
# data/train/dogs/dog267.jpg
# data/train/dogs/dog617.jpg
# data/train/dogs/dog584.jpg
# data/train/dogs/dog265.jpg
# data/train/dogs/dog625.jpg
# data/train/dogs/dog472.jpg
# data/train/dogs/dog107.jpg
# data/train/dogs/dog155.jpg
# data/train/dogs/dog691.jpg
# data/train/dogs/dog889.jpg
# data/train/dogs/dog864.jpg
# data/train/dogs/dog261.jpg
# data/train/dogs/dog978.jpg
# data/train/dogs/dog546.jpg
# data/train/dogs/dog340.jpg
# data/train/dogs/dog092.jpg
# data/train/dogs/dog307.jpg
# data/train/dogs/dog846.jpg
# data/train/dogs/dog080.jpg
# data/train/dogs/dog290.jpg
# data/train/dogs/dog445.jpg
# data/train/dogs/dog370.jpg
# data/train/dogs/dog489.jpg
# data/train/dogs/dog189.jpg
# data/train/dogs/dog599.jpg
# data/train/dogs/dog165.jpg
# data/train/dogs/dog615.jpg
# data/train/dogs/dog517.jpg
# data/train/dogs/dog033.jpg
# data/train/dogs/dog563.jpg
# data/train/dogs/dog287.jpg
# data/train/dogs/dog421.jpg
# data/train/dogs/dog391.jpg
# data/train/dogs/dog859.jpg
# data/train/dogs/dog735.jpg
# data/train/dogs/dog579.jpg
# data/train/dogs/dog531.jpg
# data/train/dogs/dog750.jpg
# data/train/dogs/dog873.jpg
# data/train/dogs/dog258.jpg
# data/train/dogs/dog986.jpg
# data/train/dogs/dog228.jpg
# data/train/dogs/dog458.jpg
# data/train/dogs/dog201.jpg
# data/train/dogs/dog713.jpg
# data/train/dogs/dog148.jpg
# data/train/dogs/dog471.jpg
# data/train/dogs/dog278.jpg
# data/train/dogs/dog516.jpg
# data/train/dogs/dog275.jpg
# data/train/dogs/dog898.jpg
# data/train/dogs/dog658.jpg
# data/train/dogs/dog683.jpg
# data/train/dogs/dog938.jpg
# data/train/dogs/dog733.jpg
# data/train/dogs/dog843.jpg
# data/train/dogs/dog018.jpg
# data/train/dogs/dog003.jpg
# data/train/dogs/dog836.jpg
# data/train/dogs/dog122.jpg
# data/train/dogs/dog443.jpg
# data/train/dogs/dog502.jpg
# data/train/dogs/dog719.jpg
# data/train/dogs/dog501.jpg
# data/train/dogs/dog023.jpg
# data/train/dogs/dog320.jpg
# data/train/dogs/dog384.jpg
# data/train/dogs/dog477.jpg
# data/train/dogs/dog183.jpg
# data/train/dogs/dog833.jpg
# data/train/dogs/dog900.jpg
# data/train/dogs/dog147.jpg
# data/train/dogs/dog230.jpg
# data/train/dogs/dog350.jpg
# data/train/dogs/dog593.jpg
# data/train/dogs/dog687.jpg
# data/train/dogs/dog937.jpg
# data/train/dogs/dog293.jpg
# data/train/dogs/dog892.jpg
# data/train/dogs/dog907.jpg
# data/train/dogs/dog454.jpg
# data/train/dogs/dog803.jpg
# data/train/dogs/dog793.jpg
# data/train/dogs/dog160.jpg
# data/train/dogs/dog341.jpg
# data/train/dogs/dog992.jpg
# data/train/dogs/dog182.jpg
# data/train/dogs/dog197.jpg
# data/train/dogs/dog141.jpg
# data/train/dogs/dog476.jpg
# data/train/dogs/dog518.jpg
# data/train/dogs/dog649.jpg
# data/train/dogs/dog760.jpg
# data/train/dogs/dog130.jpg
# data/train/dogs/dog348.jpg
# data/train/dogs/dog944.jpg
# data/train/dogs/dog399.jpg
# data/train/dogs/dog619.jpg
# data/train/dogs/dog506.jpg
# data/train/dogs/dog161.jpg
# data/train/dogs/dog948.jpg
# data/train/dogs/dog797.jpg
# data/train/dogs/dog762.jpg
# data/train/dogs/dog019.jpg
# data/train/dogs/dog613.jpg
# data/train/dogs/dog315.jpg
# data/train/dogs/dog695.jpg
# data/train/dogs/dog916.jpg
# data/train/dogs/dog330.jpg
# data/train/dogs/dog939.jpg
# data/train/dogs/dog705.jpg
# data/train/dogs/dog565.jpg
# data/train/dogs/dog595.jpg
# data/train/dogs/dog075.jpg
# data/train/dogs/dog548.jpg
# data/train/dogs/dog327.jpg
# data/train/dogs/dog392.jpg
# data/train/dogs/dog241.jpg
# data/train/dogs/dog162.jpg
# data/train/dogs/dog827.jpg
# data/train/dogs/dog447.jpg
# data/train/dogs/dog710.jpg
# data/train/dogs/dog242.jpg
# data/train/dogs/dog329.jpg
# data/train/dogs/dog351.jpg
# data/train/dogs/dog276.jpg
# data/train/dogs/dog048.jpg
# data/train/dogs/dog297.jpg
# data/train/dogs/dog549.jpg
# data/train/dogs/dog157.jpg
# data/train/dogs/dog870.jpg
# data/train/dogs/dog152.jpg
# data/train/dogs/dog395.jpg
# data/train/dogs/dog638.jpg
# data/train/dogs/dog763.jpg
# data/train/dogs/dog374.jpg
# data/train/dogs/dog270.jpg
# data/train/dogs/dog616.jpg
# data/train/dogs/dog871.jpg
# data/train/dogs/dog522.jpg
# data/train/dogs/dog515.jpg
# data/train/dogs/dog017.jpg
# data/train/dogs/dog110.jpg
# data/train/dogs/dog585.jpg
# data/train/dogs/dog404.jpg
# data/train/dogs/dog553.jpg
# data/train/dogs/dog428.jpg
# data/train/dogs/dog866.jpg
# data/train/dogs/dog651.jpg
# data/train/dogs/dog220.jpg
# data/train/dogs/dog634.jpg
# data/train/dogs/dog224.jpg
# data/train/dogs/dog540.jpg
# data/train/dogs/dog773.jpg
# data/train/dogs/dog417.jpg
# data/train/dogs/dog602.jpg
# data/train/dogs/dog234.jpg
# data/train/dogs/dog311.jpg
# data/train/dogs/dog863.jpg
# data/train/dogs/dog202.jpg
# data/train/dogs/dog142.jpg
# data/train/dogs/dog783.jpg
# data/train/dogs/dog299.jpg
# data/train/dogs/dog882.jpg
# data/train/dogs/dog032.jpg
# data/train/dogs/dog342.jpg
# data/train/dogs/dog837.jpg
# data/train/dogs/dog951.jpg
# data/train/dogs/dog088.jpg
# data/train/dogs/dog962.jpg
# data/train/dogs/dog575.jpg
# data/train/dogs/dog338.jpg
# data/train/dogs/dog462.jpg
# data/train/dogs/dog495.jpg
# data/train/dogs/dog704.jpg
# data/train/dogs/dog039.jpg
# data/train/dogs/dog922.jpg
# data/train/dogs/dog025.jpg
# data/train/dogs/dog567.jpg
# data/train/dogs/dog061.jpg
# data/train/dogs/dog785.jpg
# data/train/dogs/dog473.jpg
# data/train/dogs/dog187.jpg
# data/train/dogs/dog669.jpg
# data/train/dogs/dog049.jpg
# data/train/dogs/dog100.jpg
# data/train/dogs/dog264.jpg
# data/train/dogs/dog321.jpg
# data/train/dogs/dog373.jpg
# data/train/dogs/dog178.jpg
# data/train/dogs/dog366.jpg
# data/train/dogs/dog701.jpg
# data/train/dogs/dog673.jpg
# data/train/dogs/dog998.jpg
# data/train/dogs/dog256.jpg
# data/train/dogs/dog389.jpg
# data/train/dogs/dog901.jpg
# data/train/dogs/dog468.jpg
# data/train/dogs/dog083.jpg
# data/train/dogs/dog038.jpg
# data/train/dogs/dog175.jpg
# data/train/dogs/dog975.jpg
# data/train/dogs/dog359.jpg
# data/train/dogs/dog020.jpg
# data/train/dogs/dog411.jpg
# data/train/dogs/dog397.jpg
# data/train/dogs/dog451.jpg
# data/train/dogs/dog921.jpg
# data/train/dogs/dog527.jpg
# data/train/dogs/dog139.jpg
# data/train/dogs/dog656.jpg
# data/train/dogs/dog935.jpg
# data/train/dogs/dog965.jpg
# data/train/dogs/dog677.jpg
# data/train/dogs/dog199.jpg
# data/train/dogs/dog728.jpg
# data/train/dogs/dog572.jpg
# data/train/dogs/dog335.jpg
# data/train/dogs/dog006.jpg
# data/train/dogs/dog815.jpg
# data/train/dogs/dog950.jpg
# data/train/dogs/dog826.jpg
# data/train/dogs/dog917.jpg
# data/train/dogs/dog741.jpg
# data/train/dogs/dog010.jpg
# data/train/dogs/dog031.jpg
# data/train/dogs/dog767.jpg
# data/train/dogs/dog014.jpg
# data/train/dogs/dog231.jpg
# data/train/dogs/dog925.jpg
# data/train/dogs/dog838.jpg
# data/train/dogs/dog085.jpg
# data/train/dogs/dog845.jpg
# data/train/dogs/dog507.jpg
# data/train/dogs/dog661.jpg
# data/train/dogs/dog905.jpg
# data/train/dogs/dog987.jpg
# data/train/dogs/dog587.jpg
# data/train/dogs/dog296.jpg
# data/train/dogs/dog127.jpg
# data/train/dogs/dog424.jpg
# data/train/dogs/dog694.jpg
# data/train/dogs/dog284.jpg
# data/train/dogs/dog525.jpg
# data/train/dogs/dog383.jpg
# data/train/dogs/dog005.jpg
# data/train/dogs/dog479.jpg
# data/train/dogs/dog731.jpg
# data/train/dogs/dog263.jpg
# data/train/dogs/dog001.jpg
# data/train/dogs/dog050.jpg
# data/train/dogs/dog755.jpg
# data/train/dogs/dog604.jpg
# data/train/dogs/dog427.jpg
# data/train/dogs/dog989.jpg
# data/train/dogs/dog422.jpg
# data/train/dogs/dog995.jpg
# data/train/dogs/dog496.jpg
# data/train/dogs/dog510.jpg
# data/train/dogs/dog082.jpg
# data/train/dogs/dog913.jpg
# data/train/dogs/dog216.jpg
# data/train/dogs/dog406.jpg
# data/train/dogs/dog664.jpg
# data/train/dogs/dog125.jpg
# data/train/dogs/dog778.jpg
# data/train/dogs/dog444.jpg
# data/train/dogs/dog819.jpg
# data/train/dogs/dog030.jpg
# data/train/dogs/dog662.jpg
# data/train/dogs/dog513.jpg
# data/train/dogs/dog067.jpg
# data/train/dogs/dog034.jpg
# data/train/dogs/dog375.jpg
# data/train/dogs/dog678.jpg
# data/train/dogs/dog547.jpg
# data/train/dogs/dog402.jpg
# data/train/dogs/dog343.jpg
# data/train/dogs/dog932.jpg
# data/train/dogs/dog337.jpg
# data/train/dogs/dog954.jpg
# data/train/dogs/dog004.jpg
# data/train/dogs/dog491.jpg
# data/train/dogs/dog789.jpg
# data/train/dogs/dog824.jpg
# data/train/dogs/dog990.jpg
# data/train/dogs/dog433.jpg
# data/train/dogs/dog352.jpg
# data/train/dogs/dog024.jpg
# data/train/dogs/dog281.jpg
# data/train/dogs/dog779.jpg
# data/train/dogs/dog494.jpg
# data/train/dogs/dog326.jpg
# data/train/dogs/dog113.jpg
# data/train/dogs/dog645.jpg
# data/train/dogs/dog459.jpg
# data/train/dogs/dog918.jpg
# data/train/dogs/dog164.jpg
# data/train/dogs/dog035.jpg
# data/train/dogs/dog573.jpg
# data/train/dogs/dog188.jpg
# data/train/dogs/dog586.jpg
# data/train/dogs/dog181.jpg
# data/train/dogs/dog554.jpg
# data/train/dogs/dog637.jpg
# data/train/dogs/dog194.jpg
# data/train/dogs/dog425.jpg
# data/train/dogs/dog675.jpg
# data/train/dogs/dog596.jpg
# data/train/dogs/dog532.jpg
# data/train/dogs/dog914.jpg
# data/train/dogs/dog103.jpg
# data/train/dogs/dog660.jpg
# data/train/dogs/dog118.jpg
# data/train/dogs/dog968.jpg
# data/train/dogs/dog316.jpg
# data/train/dogs/dog285.jpg
# data/train/dogs/dog707.jpg
# data/train/dogs/dog928.jpg
# data/train/dogs/dog358.jpg
# data/train/dogs/dog007.jpg
# data/train/dogs/dog271.jpg
# data/train/dogs/dog904.jpg
# data/train/dogs/dog818.jpg
# data/train/dogs/dog580.jpg
# data/train/dogs/dog186.jpg
# data/train/dogs/dog172.jpg
# data/train/dogs/dog071.jpg
# data/train/dogs/dog840.jpg
# data/train/dogs/dog538.jpg
# data/train/dogs/dog211.jpg
# data/train/dogs/dog934.jpg
# data/train/dogs/dog251.jpg
# data/train/dogs/dog151.jpg
# data/train/dogs/dog300.jpg
# data/train/dogs/dog344.jpg
# data/train/dogs/dog941.jpg
# data/train/dogs/dog400.jpg
# data/train/dogs/dog765.jpg
# data/train/dogs/dog745.jpg
# data/train/dogs/dog558.jpg
# data/train/dogs/dog821.jpg
# data/train/dogs/dog426.jpg
# data/train/dogs/dog013.jpg
# data/train/dogs/dog505.jpg
# data/train/dogs/dog116.jpg
# data/train/dogs/dog200.jpg
# data/train/dogs/dog268.jpg
# data/train/dogs/dog217.jpg
# data/train/dogs/dog480.jpg
# data/train/dogs/dog363.jpg
# data/train/dogs/dog305.jpg
# data/train/dogs/dog581.jpg
# data/train/dogs/dog372.jpg
# data/train/dogs/dog912.jpg
# data/train/dogs/dog381.jpg
# data/train/dogs/dog011.jpg
# data/train/dogs/dog612.jpg
# data/train/dogs/dog378.jpg
# data/train/dogs/dog046.jpg
# data/train/dogs/dog403.jpg
# data/train/dogs/dog671.jpg
# data/train/dogs/dog131.jpg
# data/train/dogs/dog852.jpg
# data/train/dogs/dog492.jpg
# data/train/dogs/dog730.jpg
# data/train/dogs/dog409.jpg
# data/train/dogs/dog640.jpg
# data/train/dogs/dog109.jpg
# data/train/dogs/dog578.jpg
# data/train/dogs/dog096.jpg
# data/train/dogs/dog043.jpg
# data/train/dogs/dog644.jpg
# data/train/dogs/dog985.jpg
# data/train/dogs/dog065.jpg
# data/train/dogs/dog436.jpg
# data/train/dogs/dog317.jpg
# data/train/cats/cat630.jpg
# data/train/cats/cat267.jpg
# data/train/cats/cat001.jpg
# data/train/cats/cat701.jpg
# data/train/cats/cat857.jpg
# data/train/cats/cat954.jpg
# data/train/cats/cat863.jpg
# data/train/cats/cat490.jpg
# data/train/cats/cat417.jpg
# data/train/cats/cat806.jpg
# data/train/cats/cat320.jpg
# data/train/cats/cat846.jpg
# data/train/cats/cat804.jpg
# data/train/cats/cat376.jpg
# data/train/cats/cat841.jpg
# data/train/cats/cat927.jpg
# data/train/cats/cat408.jpg
# data/train/cats/cat842.jpg
# data/train/cats/cat114.jpg
# data/train/cats/cat882.jpg
# data/train/cats/cat301.jpg
# data/train/cats/cat262.jpg
# data/train/cats/cat066.jpg
# data/train/cats/cat664.jpg
# data/train/cats/cat477.jpg
# data/train/cats/cat299.jpg
# data/train/cats/cat457.jpg
# data/train/cats/cat171.jpg
# data/train/cats/cat723.jpg

# %% [markdown]
# The following is from [Blog script 1](https://gist.github.com/fchollet/0830affa1f7f19fd47b06d4cf89ed44d)

# %% [markdown]
# # Utility routines
# Based on:  https://www.learnopencv.com/keras-tutorial-fine-tuning-using-pre-trained-models/

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model

def plot_training(history):
  """
  Plot training and validation statistics
  - accuracy vs epoch number
  - loss     vs epoch number
  
  From https://www.learnopencv.com/keras-tutorial-fine-tuning-using-pre-trained-models/
  """  
  
  # Accuracy
  acc = history.history['acc']
  val_acc = history.history['val_acc']
  
  # Loss
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.plot(epochs, acc, 'b', label='Training acc')
  plt.plot(epochs, val_acc, 'r', label='Validation acc')
  plt.title('Training and validation accuracy')
  plt.legend()

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  plt.show()

# %%
import re
import IPython

def trainModel(model, train_data_dir, validation_data_dir):
  # compile the model with a SGD/momentum optimizer
  # and a very slow learning rate.
  model.compile(loss='binary_crossentropy',
                #optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),
                metrics=['accuracy'])

  # prepare data augmentation configuration
  train_datagen = ImageDataGenerator(
      rescale=1. / 255,
      shear_range=0.2,
      zoom_range=0.2,
      horizontal_flip=True)

  test_datagen = ImageDataGenerator(rescale=1. / 255)

  train_generator = train_datagen.flow_from_directory(
      train_data_dir,
      target_size=(img_height, img_width),
      batch_size=batch_size,
      class_mode='binary')

  validation_generator = test_datagen.flow_from_directory(
      validation_data_dir,
      target_size=(img_height, img_width),
      batch_size=batch_size,
      class_mode='binary')

  es_callback = EarlyStopping(monitor='val_loss', min_delta=.005, patience=2, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

  callbacks = [ es_callback,
                    # ModelCheckpoint(filepath=modelName + ".ckpt", monitor='acc', save_best_only=True)
                ]   
  # fine-tune the model
  history = model.fit_generator(
      train_generator,
      # samples_per_epoch=nb_train_samples,
      steps_per_epoch=nb_train_samples // batch_size,
      epochs=epochs,
      validation_data=validation_generator,
      validation_steps=nb_validation_samples // batch_size,
      callbacks=callbacks
      )
  
  
  return history

def createTransferModel(base_model, last_base_layer_name, down_conv_features=32):
  model = Sequential()

  # Find the last layer
  layer_names = [ l.name for l in base_model.layers ]
  last_base_layer_idx = layer_names.index(last_base_layer_name)

  print("Last layer {ll:s} is index {i:d}".format(ll=last_base_layer_name, i=last_base_layer_idx))
  for i, layer in enumerate(base_model.layers[:last_base_layer_idx+1]):
    model.add(layer)
    layer.trainable=False
  
  # Add down sampling
  model.add( Conv2D(down_conv_features, kernel_size=(1, 1), activation='relu') )

  # Add head
  model.add(Flatten())
  model.add(Dense(32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(1, activation='sigmoid'))


  return model

def plotModel(model, modelName):
  plotFile = modelName + ".png"
  plot_model(model, plotFile, show_shapes=True)

  return plotFile

# %% [markdown]
# # Problem description
# - Binary classification problem, with small quantity of training data
#
# - Cats and Dogs dataset:
#   - a *small* number of examples
#   - two classes: Cats, Dogs
#
# Plan
# 1. Create and train own model
# 1. Transfer Learning
#   - use the prefix of a pre-trained model
#   - add own suffix

# %%
'''This script goes along the blog post
"Building powerful image classification models using very little data"
from blog.keras.io.
It uses data that can be downloaded at:
https://www.kaggle.com/c/dogs-vs-cats/data
In our setup, we:
- created a data/ folder
- created train/ and validation/ subfolders inside data/
- created cats/ and dogs/ subfolders inside train/ and validation/
- put the cat pictures index 0-999 in data/train/cats
- put the cat pictures index 1000-1400 in data/validation/cats
- put the dogs pictures index 12500-13499 in data/train/dogs
- put the dog pictures index 13500-13900 in data/validation/dogs
So that we have 1000 training examples for each class, and 400 validation examples for each class.
In summary, this is our directory structure:
```
data/
    train/
        dogs/
            dog001.jpg
            dog002.jpg
            ...
        cats/
            cat001.jpg
            cat002.jpg
            ...
    validation/
        dogs/
            dog001.jpg
            dog002.jpg
            ...
        cats/
            cat001.jpg
            cat002.jpg
            ...
```
'''

# dimensions of our images.
img_width, img_height = 150, 150
image_size = 150
IMG_SHAPE = (image_size, image_size, 3)

train_data_dir = 'data/train'
validation_data_dir = 'data/validation'
nb_train_samples = 2000
nb_validation_samples = 800
epochs = 50
batch_size = 16


def createFirstModel():
  if tf.keras.backend.image_data_format() == 'channels_first':
      input_shape = (3, img_width, img_height)
  else:
      input_shape = (img_width, img_height, 3)

  model = Sequential()
  model.add(Conv2D(32, (3, 3), input_shape=input_shape))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))

  model.add(Conv2D(32, (3, 3)))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))

  model.add(Conv2D(64, (3, 3)))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))

  model.add(Flatten())
  model.add(Dense(64))
  model.add(Activation('relu'))
  model.add(Dropout(0.5))
  model.add(Dense(1))
  model.add(Activation('sigmoid'))

  return model

# %% [markdown]
# # Create own model
# - multiple Conv2D/Pooling blocks

# %%
first_model = createFirstModel()
plotFile = plotModel(first_model, "first_model")
IPython.display.Image( plotFile)

# %%
first_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 148, 148, 32)      896
# _________________________________________________________________
# activation_15 (Activation)   (None, 148, 148, 32)      0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 72, 72, 32)        9248
# _________________________________________________________________
# activation_16 (Activation)   (None, 72, 72, 32)        0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 34, 34, 64)        18496
# _________________________________________________________________
# activation_17 (Activation)   (None, 34, 34, 64)        0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                1183808
# _________________________________________________________________
# activation_18 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_19 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 1,212,513
# Trainable params: 1,212,513
# Non-trainable params: 0
# _________________________________________________________________

# %%
first_history = trainModel(first_model, train_data_dir, validation_data_dir  )
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# Epoch 1/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.7073 - acc: 0.5227Epoch 1/50
# 125/125 [==============================] - 22s 176ms/step - loss: 0.7073 - acc: 0.5225 - val_loss: 0.9897 - val_acc: 0.5000
# Epoch 2/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.6942 - acc: 0.5857Epoch 1/50
# 125/125 [==============================] - 20s 156ms/step - loss: 0.6936 - acc: 0.5860 - val_loss: 0.6303 - val_acc: 0.6637
# Epoch 3/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.6436 - acc: 0.6416Epoch 1/50
# 125/125 [==============================] - 20s 160ms/step - loss: 0.6433 - acc: 0.6415 - val_loss: 0.6005 - val_acc: 0.6650
# Epoch 4/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.6144 - acc: 0.6658Epoch 1/50
# 125/125 [==============================] - 20s 160ms/step - loss: 0.6137 - acc: 0.6665 - val_loss: 0.5948 - val_acc: 0.6938
# Epoch 5/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.5912 - acc: 0.6930Epoch 1/50
# 125/125 [==============================] - 20s 160ms/step - loss: 0.5906 - acc: 0.6930 - val_loss: 0.5739 - val_acc: 0.7113
# Epoch 6/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.5804 - acc: 0.7077Epoch 1/50
# 125/125 [==============================] - 20s 162ms/step - loss: 0.5825 - acc: 0.7080 - val_loss: 0.5787 - val_acc: 0.7025
# Epoch 7/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.5550 - acc: 0.7198Epoch 1/50
# 125/125 [==============================] - 20s 162ms/step - loss: 0.5560 - acc: 0.7190 - val_loss: 0.5798 - val_acc: 0.7038

# %%
first_model.save_weights('first_try.h5')

# %%
plot_training(first_history)

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import load_img

def show_errors(model, data_generator, data_dir, start=0, end=None):
  """
  Show misclassified images
  
  Adapted from: https://www.learnopencv.com/keras-tutorial-fine-tuning-using-pre-trained-models/
  
  data_generator generates images to classify
  - n.b., shuffle=False should be set when constructing this generator
  --- this is b/c when we ask the generator for .filenames and .classes  it is deterministic
  ---- the .classes form the "ground truth" against which predictions are evaluated so the order of examples must be deterministic
  Parameters
  -----------
  model: model for prediction
  data_generator: generator for data
  data_dir: the directory from which the generator obtains its data
  start, end: Integers.  Indices for first and last error (first error is 0)
  """

  # Get the filenames from the generator
  fnames = data_generator.filenames

  # Get the ground truth from generator
  ground_truth = data_generator.classes

  # Get the label to class mapping from the generator
  # i.e., { "class 0": 0, "class 1": 1, ... }
  label2index = xvalidation_generator.class_indices

  # Getting the mapping from class index to class label
  idx2label = dict((v,k) for k,v in label2index.items())

  # Get the predictions from the model using the generator
  predictions = model.predict_generator(data_generator, steps=data_generator.samples/data_generator.batch_size,verbose=1)

  # Handle special case where prediction is binary, not categorical
  # convert it into 2 categories
  if predictions.shape[-1] == 1:
    predictions = np.c_[ 1-predictions, predictions]

  predicted_classes = np.argmax(predictions,axis=1)

  # errors: list of indices where prediction is wrong
  errors = np.where(predicted_classes != ground_truth)[0]
  print("No of errors = {}/{}".format(len(errors),data_generator.samples))
  
  if end is None:
    end = len(errors)
    
  # Show the errors
  for i in range(start, end):
      pred_class = np.argmax(predictions[errors[i]])
      pred_label = idx2label[pred_class]

      title = 'Original label:{}, Prediction :{}, confidence : {:.3f}'.format(
          fnames[errors[i]].split('/')[0],
          pred_label,
          predictions[errors[i]][pred_class])

      original = load_img('{}/{}'.format(data_dir,fnames[errors[i]]))
      plt.figure(figsize=[7,7])
      plt.axis('off')
      plt.title(title)
      plt.imshow(original)
      plt.show()

# %%
test_datagen = ImageDataGenerator(rescale=1. / 255)

# Need validation set to NOT be shuffled
#- n.b., shuffle=False should be set when constructing this generator
#  --- this is b/c when we ask the generator for .filenames and .classes  it is deterministic
#  ---- the .classes form the "ground truth" against which predictions are evaluated so the order of examples must be deterministic
xvalidation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)

show_errors(first_model, xvalidation_generator, validation_data_dir, start=1, end=10)
# Out:
# Found 800 images belonging to 2 classes.
# 50/50 [==============================] - 3s 58ms/step
# No of errors = 231/800

# %% [markdown]
# # Load a pre-trained VGG16 model

# %%
base_model = tf.keras.applications.VGG16(input_shape=IMG_SHAPE,
                                     include_top=False, 
                                     weights='imagenet')

plotFile = plotModel(base_model, "vgg16_model")
IPython.display.Image( plotFile)

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Transfer Learning: Graft a new head onto VGG 16

# %%
transf_model = createTransferModel(base_model,  base_model.layers[-1].name)
transf_model.summary()
# Out:
# Last layer block5_pool is index 18
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 4, 4, 32)          16416
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                16416
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 14,747,553
# Trainable params: 32,865
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
transf_history = trainModel(transf_model, train_data_dir, validation_data_dir)
plot_training(transf_history)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# Epoch 1/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.5180 - acc: 0.7288Epoch 1/50
# 125/125 [==============================] - 27s 215ms/step - loss: 0.5182 - acc: 0.7290 - val_loss: 0.3309 - val_acc: 0.8775
# Epoch 2/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.3720 - acc: 0.8347Epoch 1/50
# 125/125 [==============================] - 24s 194ms/step - loss: 0.3773 - acc: 0.8330 - val_loss: 0.2825 - val_acc: 0.8863
# Epoch 3/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.3283 - acc: 0.8609Epoch 1/50
# 125/125 [==============================] - 24s 195ms/step - loss: 0.3279 - acc: 0.8605 - val_loss: 0.2750 - val_acc: 0.8950
# Epoch 4/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.3120 - acc: 0.8740Epoch 1/50
# 125/125 [==============================] - 23s 185ms/step - loss: 0.3122 - acc: 0.8730 - val_loss: 0.2776 - val_acc: 0.8813
# Epoch 5/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.2771 - acc: 0.8896Epoch 1/50
# 125/125 [==============================] - 24s 195ms/step - loss: 0.2768 - acc: 0.8900 - val_loss: 0.2429 - val_acc: 0.9038
# Epoch 6/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.2427 - acc: 0.9002Epoch 1/50
# 125/125 [==============================] - 23s 188ms/step - loss: 0.2417 - acc: 0.9005 - val_loss: 0.2603 - val_acc: 0.8963
# Epoch 7/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.2311 - acc: 0.9083Epoch 1/50
# 125/125 [==============================] - 23s 186ms/step - loss: 0.2313 - acc: 0.9085 - val_loss: 0.2555 - val_acc: 0.9025

# %% [markdown]
# # Transfer Learning: Graft a new suffix onto a VGG16 prefix
# - Do we do better or worse but elminating later layers of VGG 16 (perhaps too specialized ?)

# %%
transf_model = createTransferModel(base_model, 'block4_pool')
# Out:
# Last layer block4_pool is index 14

# %%
transf_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 9, 9, 32)          16416
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                82976
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 7,734,689
# Trainable params: 99,425
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
transf_history = trainModel(transf_model, train_data_dir, validation_data_dir)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# Epoch 1/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.7790 - acc: 0.6099Epoch 1/50
# 125/125 [==============================] - 24s 191ms/step - loss: 0.7755 - acc: 0.6125 - val_loss: 0.4540 - val_acc: 0.8012
# Epoch 2/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.4564 - acc: 0.8054Epoch 1/50
# 125/125 [==============================] - 22s 180ms/step - loss: 0.4544 - acc: 0.8055 - val_loss: 0.2948 - val_acc: 0.8737
# Epoch 3/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.3355 - acc: 0.8579Epoch 1/50
# 125/125 [==============================] - 22s 177ms/step - loss: 0.3335 - acc: 0.8590 - val_loss: 0.3597 - val_acc: 0.8537
# Epoch 4/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.2909 - acc: 0.8911Epoch 1/50
# 125/125 [==============================] - 23s 185ms/step - loss: 0.2910 - acc: 0.8900 - val_loss: 0.2529 - val_acc: 0.8950
# Epoch 5/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.2349 - acc: 0.9098Epoch 1/50
# 125/125 [==============================] - 23s 181ms/step - loss: 0.2336 - acc: 0.9105 - val_loss: 0.2754 - val_acc: 0.8988
# Epoch 6/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.2149 - acc: 0.9239Epoch 1/50
# 125/125 [==============================] - 23s 184ms/step - loss: 0.2135 - acc: 0.9245 - val_loss: 0.2324 - val_acc: 0.9162
# Epoch 7/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.1794 - acc: 0.9294Epoch 1/50
# 125/125 [==============================] - 23s 184ms/step - loss: 0.1785 - acc: 0.9300 - val_loss: 0.2985 - val_acc: 0.9125
# Epoch 8/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.1780 - acc: 0.9345Epoch 1/50
# 125/125 [==============================] - 24s 191ms/step - loss: 0.1796 - acc: 0.9335 - val_loss: 0.3520 - val_acc: 0.8988

# %%
plot_training(transf_history)

# %% [markdown]
# # Transfer Learning: Graft a new head onto *an even shorter* prefix of VGG 16.
# - Can we still learn ?

# %%
transf_model = createTransferModel(base_model, 'block3_pool')
transf_model.summary()
# Out:
# Last layer block3_pool is index 10
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 18, 18, 32)        8224
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 10368)             0
# _________________________________________________________________
# dense_14 (Dense)             (None, 32)                331808
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 2,075,553
# Trainable params: 340,065
# Non-trainable params: 1,735,488
# _________________________________________________________________

# %%
transf_history = trainModel(transf_model, train_data_dir, validation_data_dir)
plot_training(transf_history)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# Epoch 1/50
# 124/125 [============================>.] - ETA: 0s - loss: 1.8796 - acc: 0.5030Epoch 1/50
# 125/125 [==============================] - 25s 197ms/step - loss: 1.8701 - acc: 0.5025 - val_loss: 0.6911 - val_acc: 0.5113
# Epoch 2/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.7658 - acc: 0.5197Epoch 1/50
# 125/125 [==============================] - 22s 177ms/step - loss: 0.7642 - acc: 0.5215 - val_loss: 0.6400 - val_acc: 0.5537
# Epoch 3/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.7401 - acc: 0.5847Epoch 1/50
# 125/125 [==============================] - 21s 172ms/step - loss: 0.7391 - acc: 0.5860 - val_loss: 0.5352 - val_acc: 0.7063
# Epoch 4/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.6477 - acc: 0.6502Epoch 1/50
# 125/125 [==============================] - 21s 170ms/step - loss: 0.6501 - acc: 0.6495 - val_loss: 0.5058 - val_acc: 0.7500
# Epoch 5/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.5910 - acc: 0.7092Epoch 1/50
# 125/125 [==============================] - 22s 177ms/step - loss: 0.5899 - acc: 0.7100 - val_loss: 0.4755 - val_acc: 0.7775
# Epoch 6/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.5596 - acc: 0.7359Epoch 1/50
# 125/125 [==============================] - 23s 182ms/step - loss: 0.5581 - acc: 0.7365 - val_loss: 0.5746 - val_acc: 0.7763
# Epoch 7/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.5323 - acc: 0.7692Epoch 1/50
# 125/125 [==============================] - 22s 177ms/step - loss: 0.5314 - acc: 0.7695 - val_loss: 0.4352 - val_acc: 0.8062
# Epoch 8/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.5100 - acc: 0.7616Epoch 1/50
# 125/125 [==============================] - 22s 175ms/step - loss: 0.5094 - acc: 0.7610 - val_loss: 0.4563 - val_acc: 0.8075
# Epoch 9/50
# 124/125 [============================>.] - ETA: 0s - loss: 0.5036 - acc: 0.7787Epoch 1/50
# 125/125 [==============================] - 22s 176ms/step - loss: 0.5033 - acc: 0.7785 - val_loss: 0.4323 - val_acc: 0.8087
